# %% [markdown]
# <a href="https://colab.research.google.com/github/iasaurav/end_algotrading/blob/main/fyers3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==============================
# DAILY AUTO SCRIPT FOR FYERS
# ==============================
from datetime import datetime

today = datetime.now().day

if 5 <= today <= 20:
    print("Running: token_refresh.py")
    # !python /content/drive/MyDrive/Fyers/token_refresh.py

elif today == 21:
    print("Installing fyers-apiv3 and running refresh.py")
    # !pip install fyers-apiv3 --quiet
    # !python /content/drive/MyDrive/Fyers/refresh.py

elif 22 <= today <= 30:
    print("Running: token_refresh.py")
    # !python /content/drive/MyDrive/Fyers/token_refresh.py

else:
    print("No action for today.")
# Out:
# Running: token_refresh.py
# Time: 06-12-2025 04:33:58 PM
# ready for trading
